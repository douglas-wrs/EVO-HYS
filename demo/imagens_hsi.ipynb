# %%
import sys
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)
sys.path.append('../source/endmembers')

# %%
import copy
import math
import time
import random
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
from tqdm import tqdm
from spectral import *
from scipy import linalg
from collections import deque
from numpy.random import rand
from numpy import linalg as la
import matplotlib.pyplot as plt
from sklearn import preprocessing
import helpers.auxiliar as auxiliar

# %%
[Y,
 img,
 dimensions, 
 number_endmembers,
 ground_truth,
 ground_truth_plot,
 endmembers_names,
 dimensions_plot,
 bandsSelection,
 dataset_name] = auxiliar.load_legendre_dataset(0)
view = imshow(img, (128, 128, 430))
plt.axis('off');

# %%
[Y,
 img,
 dimensions, 
 number_endmembers,
 ground_truth,
 ground_truth_plot,
 endmembers_names,
 dimensions_plot,
 bandsSelection,
 dataset_name] = auxiliar.load_legendre_dataset(20)
view = imshow(img, (128, 128, 430))
plt.axis('off');

# %%
[Y,
 img,
 dimensions, 
 number_endmembers,
 ground_truth,
 ground_truth_plot,
 endmembers_names,
 dimensions_plot,
 bandsSelection,
 dataset_name] = auxiliar.load_legendre_dataset(40)
view = imshow(img, (128, 128, 430))
plt.axis('off');

# %%
[Y,
 img,
 dimensions, 
 number_endmembers,
 ground_truth,
 ground_truth_plot,
 endmembers_names,
 dimensions_plot,
 bandsSelection,
 dataset_name] = auxiliar.load_legendre_dataset(80)
view = imshow(img, (128, 128, 430))
plt.axis('off');
